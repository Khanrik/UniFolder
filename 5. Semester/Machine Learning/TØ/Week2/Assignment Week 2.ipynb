# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from math import  exp

import seaborn as sns; sns.set(); sns.set_palette('bright')

# %% [markdown]
# ## 1) What is the probability of observing a measurement with value of $x < 6$?

# %% [markdown]
# First the probabilites of the two classes can be found
# \begin{align*}
# P(C_{1}) + P(C_{2}) &= 1\\
# 2P(C_{2}) + P(C_{2}) &= 1\\
# P(C_{2}) &= \frac{1}{3}
# \end{align*}
#
# $$
# P(C_{1}) = 2P(C_{2}) = \frac{2}{3}
# $$
#
# Following the law of total probability
# $$
# P(x < 6) = P(x < 6 | C_{1}) \cdot P(C_{1}) + P(x < 6 | C_{2}) \cdot P(C_{2})
# $$

# %%
a = 0.42
c = 0.22
d = 0.2
e = 0.17
f = 0.12
g = 0.07
h = 0.04

(f + c + a + e + g) * 2/3 + (h + d) * 1/3
# Out:
# 0.7466666666666666

# %% [markdown]
# ### 2) What is the probability of a measurement belonging to $C_{1}$ to have a value of $x < 6$?

# %% [markdown]
# Since all the observations belonging to $C_{1}$ are values under $x<6$, the probability is
# $$
# P(x<6 | C_{1}) = 1
# $$

# %% [markdown]
# ### 3) Describe a way to classify a measurement with value of $x = 4.5$ to one of the two classes using the probability and loss values provided in this exercise.

# %% [markdown]
# Week 4 slide 8
