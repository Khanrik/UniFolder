# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
omega = np.linspace(-4*np.pi, 4*np.pi, 1000)
x = (3/4) / (5/4 - np.cos(omega))
ax.plot(omega, x)

# %%
np.abs(1 + 1j)
# Out:
# 1.4142135623730951
