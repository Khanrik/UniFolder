# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Section 1.4

# %% [markdown]
# Find general solutions (implicit if necessary, explicit if convenient) of the differential equations in Problems 1 through 18. Primes denote derivatives with respect to $x$.

# %% [markdown]
# ### Problem 1
# $\frac{dy}{dx} + 2xy = 0$

# %% [markdown]
# Standard form defines $P(x) = 2xy$ and $Q(x) = 0$
# \begin{align*}
# v(x) &= e^{\int 2xy \, dx}\\
# &= e^{x^{2}y}\\
# \end{align*}
#
# \begin{align*}
# y &= \frac{1}{e^{x^{2}y}} \int e^{x^{2}y} \cdot 0 \, dx\\
# &= e^{-x^{2}y} \cdot C
# \end{align*}

# %% [markdown]
# ### Problem 2
