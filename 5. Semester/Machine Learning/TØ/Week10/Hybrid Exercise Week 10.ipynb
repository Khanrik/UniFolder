# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You are given a set of data points $x_i \in \mathbb{R}^8, i = 1, \dots, N$, each followed by a five-dimensional target $t_i \in \mathbb{R}^5, i = 1, \dots, N$. You want to use a feedforward neural network formed by three hidden-layers for solving this regression problem.

# %% [markdown]
# ## 1) Describe which are the parameters and the hyper-parameters of the neural network. Use appropriate mathematical symbols (e.g., matrices, functions).

# %% [markdown]
# The parameters of the neural network are the parts that are learnt through training e.g. the weights and biases, $W^{(1)}, W^{(2)}, W^{(3)}, W^{(out)}$ and $b^{(1)}, b^{(2)}, b^{(3)}, b^{(out)}$. Since there are 3 hidden layers, there will be 3 pairs of weigths and baises for each as well as a pair for the output layer.
#
# The hyperparamaters are the parts set before training, which is the network architecture (number of layers and size of layers) and activation functions.

# %% [markdown]
# ## 2) Draw a neural network that can be used to solve the above-described classification problem. Make appropriate decisions for all the hyper-parameters of the neural network. In your drawing include also all the parameters of the neural network and the activation functions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Describe how to estimate the values of the neural network parameters and its hyper-parameters.

# %% [markdown]
# The hyper-parameters of the neural network is chosen by the implementer of the network based on use case. The parameters are adjusted through training (backpropagation) to minimize a cost function also set by the implementer of the network.

# %% [markdown]
# ## 4) Write down which optimization problem (loss function) you will use to train the network, and describe all terms (including the dimensions of each matrix/vector). Why is this optimization problem used when we optimize the neural network for solving a regression problem?

# %% [markdown]
# ## 5) Show why using the linear activation function (for all layers of the network) makes the above neural network not capable to achieve good performance in nonlinear regression problems. To do this, write down the equivalent, but simplified, neural network for this case, and draw it. Assume that the bias values for all neurons are equal to zero.

# %% [markdown]
# ## 6) If you were going to use linear activation functions for all the layers of the neural network, how would you optimize the parameters of the neural network? Explain why you would have to use that optimization process.

# %% [markdown]
# ## 7) How would the neural network trained following the process in question 6 compare to using a linear regression model?
