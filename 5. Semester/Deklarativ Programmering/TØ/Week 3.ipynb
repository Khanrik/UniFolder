# %% [markdown]
# Consider the following lambda terms:
#
# a. $5$
#
# b. $w$
#
# c. $y + 1$
#
# d. $(\lambda x \; y \cdot x + y) \; 1 \; 2$
#
# e. $(\lambda x \; y \cdot f)$
#
# f. $(\lambda x \; y \cdot x) \; 1 \; 2$
#
# g. $\lambda x \; y \cdot y \; (\lambda v \cdot v v)$
#
# h. $(\lambda g \cdot g \; 5)(\lambda x \cdot x + 1)$
#
# ## (1) Complete the execises for each lambda term above. You should assume that we can evaluate arithmetic expressions, and that arithmetic comparisons are correctly swapped for lambda terms “true” and “false” (as we did in the lecture). {-}

# %% [markdown]
# ### 1. Name the type of lambda term {-}

# %% [markdown]
# a. Constant
#
# b. Variable
#
# c. Combination
#
# d. Combination
#
# e. Abstraction
#
# f. Combination
#
# g. Combination
#
# h. Combination

# %% [markdown]
# ### 2. Rewrite all lambda terms in their fully curried form. {-}

# %% [markdown]
# Only the $\lambda x y$ terms are rewritten since the others are already in "curried" form.
#
# d. $(\lambda x \cdot (\lambda y \cdot x + y)) \; 1 \; 2$
#
# e. $(\lambda x \cdot (\lambda y \cdot f))$
#
# f. $(\lambda x \cdot (\lambda y \cdot x)) \; 1 \; 2$
#
# g. $(\lambda x \cdot (\lambda y \cdot y)) (\lambda v \cdot v v)$

# %% [markdown]
# ### 4. Specify the free variables in each lambda term. Hint: follow the definition of free variables like we discussed in lectures, by stepping through your tree diagrams. {-}

# %% [markdown]
# a. There are no variables only a constant.
#
# b. $w$ is a free variable.
#
# c. $y$ is a free variable.
#
# d. There are no free variables, since $x$ and $y$ are bound.
#
# e. $f$ is a free variable.
#
# f. There are no free variables, since $x$ and $y$ are bound.
#
# g. There are no free variables, since $x$, $y$, and $v$ are bound.
#
# h There are no free variables, since $x$ and $g$ are bound.

# %% [markdown]
# ### 5. Specify the bound variables in each lambda term. {-}

# %% [markdown]
# a. There are no variables only a constant.
#
# b. There are no bound variables, since $w$ is free.
#
# c. There are no bound variables, since $y$ is free.
#
# d. $x$ and $y$ are bound.
#
# e. $x$ and $y$ are bound.
#
# f. $x$ and $y$ are bound.
#
# g. $x$, $y$, and $v$ are bound.
#
# h. $x$ and $g$ are bound.

# %% [markdown]
# ### 6. Use beta reduction to reduce each lambda term until no further beta reductions can be applied. Show all working, including substitution steps. {-}

# %% [markdown]
# a. This term cannot be reduced further.
#
# b. This term cannot be reduced further.
#
# c. This term cannot be reduced further.
#
# d.
# \begin{align*}
# &(\lambda x \; y \cdot x + y) \; 1 \; 2\\
# \to_{\beta} &\quad (\lambda y \cdot x + y) [1/x] 2\\
# \to_{\beta} &\quad (1 + y)[2/y]\\
# \to_{\beta} &\quad (1 + 2)
# \end{align*}
#
# e. Since we don't know what $x$ and $y$ should be substituted with, this term cannot be reduced further.
#
# f.
# \begin{align*}
# &(\lambda x \; y \cdot x) \; 1 \; 2\\
# \to_{\beta} &\quad (\lambda y \cdot x) [1/x] 2\\
# \to_{\beta} &\quad (1)[2/y]\\
# \to_{\beta} &\quad (1)
# \end{align*}
#
# g.
# \begin{align*}
# &\lambda x \; y \cdot y \; (\lambda v \cdot v v)\\
# \to_{\beta} &\quad (\lambda y \cdot y) [(\lambda v \cdot v \; v)/x]\\
# \to_{\beta} &\quad (\lambda y \cdot y)
# \end{align*}
#
# h.
# \begin{align*}
# &(\lambda g \cdot g \; 5)(\lambda x \cdot x + 1)\\
# \to_{\beta} &\quad (g \; 5)[(\lambda x \cdot x + 1) / g]\\
# \to_{\beta} &\quad ((\lambda x \cdot x + 1) \; 5)\\
# \to_{\beta} &\quad ((x+1)[5/x])\\
# \to_{\beta} &\quad (5 + 1)
# \end{align*}

# %% [markdown]
# ## (2) In the lecture we discussed the mul_rec function. In Lecture 4 you will also discuss a so-called “tail recursive” implementation: {-}
# ```ocaml
# let rec mul_tail_rec x y a =
#     if y = 0
#     then a
#     else mul_tail_rec x (y - 1) (x + a)
# ```

# %% [markdown]
# ### 1. Express the tail recursive implementation as a lambda term; call your function `f` for brevity. {-}

# %% [markdown]
# $$
# f =_{def} \lambda x \; y \; a \cdot (y = 0) \; (a) \; (f \; x \; (y - 1) \; (x + a))
# $$

# %% [markdown]
# ### 2. Use your definition of `f` to beta reduce the following expression: `f 2 3 0`. For beta reduction steps you can skip the intermediate substitution steps if you prefer. {-}

# %% [markdown]
# \begin{align*}
# &f \; 2 \; 3 \; 0\\
# \to &\quad (\lambda x \; y \; a \cdot (y = 0) \; (a) \; (f \; x \; (y - 1) \; (x + a))) \; 2 \; 3 \; 0 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad ((3 = 0) \; (0) \; ((f \; 2 \; (3 - 1) \; (2 + 0)))) \quad \text{beta reduction}\\
# \to &\quad (\text{false} \; (0) \; (f \; 2 \; (2) \; (2))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (0) \; (f \; 2 \; (2) \; (2))) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (f \; 2 \; (2) \; (2)) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \; y \; a \cdot (y = 0) \; (a) \; (f \; x \; (y - 1) \; (x + a))) \; 2 \; 2 \; 2 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad ((2 = 0) \; (2) \; ((f \; 2 \; (2 - 1) \; (2 + 2)))) \quad \text{beta reduction}\\
# \to &\quad (\text{false} \; (2) \; (f \; 2 \; (1) \; (4))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (2) \; (f \; 2 \; (1) \; (4))) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (f \; 2 \; (1) \; (4)) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \; y \; a \cdot (y = 0) \; (a) \; (f \; x \; (y - 1) \; (x + a))) \; 2 \; 1 \; 4 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad ((1 = 0) \; (4) \; ((f \; 2 \; (1 - 1) \; (2 + 4)))) \quad \text{beta reduction}\\
# \to &\quad (\text{false} \; (4) \; (f \; 2 \; (0) \; (6))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (4) \; (f \; 2 \; (0) \; (6))) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (f \; 2 \; (0) \; (6)) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \; y \; a \cdot (y = 0) \; (a) \; (f \; x \; (y - 1) \; (x + a))) \; 2 \; 0 \; 6 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad ((0 = 0) \; (6) \; ((f \; 2 \; (0 - 1) \; (2 + 6)))) \quad \text{beta reduction}\\
# \to &\quad (\text{true} \; (6) \; (f \; 2 \; (- 1) \; (8))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot x) \; (6) \; (f \; 2 \; (- 1) \; (8))) \quad \text{substituting definition of "true"}\\
# \to_{\beta} &\quad 6 \quad \text{beta reduction}
# \end{align*}

# %% [markdown]
# ### (3) In Lecture 4 you will discuss recursive even and odd functions: {-}
# ```ocaml
# let rec even_rec x =
#     if x = 0
#     then true
#     else odd_rec (x - 1)
# and odd_rec x =
#     if x = 0
#     then false
#     else even_rec (x - 1)
# ```

# %% [markdown]
# ### 1. Express `even_rec` and `odd_rec` as lambda terms; you can call them `f` and `g` for brevity. {-}

# %% [markdown]
# $$
# f =_{def} \lambda x \cdot (x = 0) \; (\lambda x \; y \cdot x) \; (g \; (x - 1))
# $$

# %% [markdown]
# $$
# g =_{def} \lambda x \cdot (x = 0) \; (\lambda x \; y \cdot y) \; (f \; (x - 1))
# $$

# %% [markdown]
# ### 2. Use your definition of `f` and `g` to beta reduce the following expressions: `f 2` and `f 1`. For beta reduction steps you can skip the intermediate substitution steps if you prefer. {-}

# %% [markdown]
# \begin{align*}
# &f \; 2\\
# \to &\quad (\lambda x \cdot (x = 0) \; (\lambda x \; y \cdot x) \; (g \; (x - 1))) \; 2 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad (2 = 0) \; (\lambda x \; y \cdot x) \; (g \; (2 - 1)) \quad \text{beta reduction}\\
# \to &\quad ((\text{false}) \; (\lambda x \; y \cdot x) \; (f \; 1)) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (\lambda x \; y \cdot x) \; (g \; 1)) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (g \; 1) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \cdot (x = 0) \; (\lambda x \; y \cdot y) \; (f \; (x - 1))) \; 1 \quad \text{by substituting definition of "g"}\\
# \to_{\beta} &\quad (1 = 0) \; (\lambda x \; y \cdot y) \; (f \; (1 - 1)) \quad \text{beta reduction}\\
# \to &\quad ((\text{false}) \; (\lambda x \; y \cdot y) \; (f \; 0)) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (\lambda x \; y \cdot y) \; (f \; 0)) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (f \; 0) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \cdot (x = 0) \; (\lambda x \; y \cdot x) \; (g \; (x - 1))) \; 0 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad (0 = 0) \; (\lambda x \; y \cdot x) \; (g \; (0 - 1)) \quad \text{beta reduction}\\
# \to &\quad ((\text{true}) \; (\lambda x \; y \cdot x) \; (g \; (-1))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot x) \; (\lambda x \; y \cdot x) \; (g \; (-1))) \quad \text{substituting definition of "true"}\\
# \to_{\beta} &\quad \lambda x \; y \cdot x \quad \text{beta reduction}
# \end{align*}

# %% [markdown]
# \begin{align*}
# & f \; 1\\
# \to &\quad (\lambda x \cdot (x = 0) \; (\lambda x \; y \cdot x) \; (g \; (x - 1))) \; 1 \quad \text{by substituting definition of "f"}\\
# \to_{\beta} &\quad (1 = 0) \; (\lambda x \; y \cdot x) \; (g \; (1 - 1)) \quad \text{beta reduction}\\
# \to &\quad ((\text{false}) \; (\lambda x \; y \cdot x) \; (g \; 0)) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot y) \; (\lambda x \; y \cdot x) \; (g \; 0)) \quad \text{substituting definition of "false"}\\
# \to_{\beta} &\quad (g \; 0) \quad \text{beta reduction}\\
# \to &\quad (\lambda x \cdot (x = 0) \; (\lambda x \; y \cdot y) \; (f \; (x - 1))) \; 0 \quad \text{by substituting definition of "g"}\\
# \to_{\beta} &\quad (0 = 0) \; (\lambda x \; y \cdot y) \; (f \; (0 - 1)) \quad \text{beta reduction}\\
# \to &\quad ((\text{true}) \; (\lambda x \; y \cdot y) \; (f \; (-1))) \quad \text{arithmetic}\\
# \to &\quad ((\lambda x \; y \cdot x) \; (\lambda x \; y \cdot y) \; (f \; (-1))) \quad \text{substituting definition of "true"}\\
# \to_{\beta} &\quad \lambda x \; y \cdot y \quad \text{beta reduction}
# \end{align*}
