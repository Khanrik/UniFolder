# %%
#use_output "dune top"
#directory "lib"
#use "BinTree.ml"
# Out:
# type 'a tree = Node of 'a * 'a tree * 'a tree | Leaf
# val string_of_tree : ('a -> string) -> int -> 'a tree -> string = <fun>
# val mem : 'a -> 'a tree -> bool = <fun>
# val insert : 'a -> 'a tree -> 'a tree = <fun>
# type color = Red | Black
# val string_of_color : color -> string = <fun>
# type 'a rbtree = RBNode of color * 'a * 'a rbtree * 'a rbtree | RBLeaf
# val string_of_rbtree : ('a -> string) -> int -> 'a rbtree -> string = <fun>
# val rbmem : 'a -> 'a rbtree -> bool = <fun>
# val balance : color * 'a * 'a rbtree * 'a rbtree -> 'a rbtree = <fun>
# val rbinsert : 'a -> 'a rbtree -> 'a rbtree = <fun>
# val rbfill : 'a list -> 'a rbtree = <fun>
# val rbmap : ('a -> 'b) -> 'a rbtree -> 'b rbtree = <fun>
# val rbf0 : 'a rbtree -> 'a list rbtree = <fun>
# val rbvisit : ('a -> 'b -> 'b) -> 'b -> 'a rbtree -> 'b = <fun>
# val rbf1 : 'a rbtree -> 'a list = <fun>
# val rbf2 : int rbtree -> int = <fun>
# val rbf3 : 'a rbtree -> 'a tree = <fun>
# ...

# %%
let t0 = 
Node (5, 
  Node (2, 
    Node (1, Leaf, Leaf), 
    Node (3, Leaf, 
      Node (4, Leaf, Leaf))), 
  Node (8, 
    Node (7, 
      Node (6, Leaf, Leaf), Leaf), 
    Node (9, Leaf, Leaf)))
# Out:
# val t : int tree =
#   Node (5,
#    Node (2, Node (1, Leaf, Leaf), Node (3, Leaf, Node (4, Leaf, Leaf))),
#    Node (8, Node (7, Node (6, Leaf, Leaf), Leaf), Node (9, Leaf, Leaf)))

# %%
let t1 = 
RBNode (Black, 2, 
  RBNode (Black, 1, RBLeaf, RBLeaf), 
  RBNode (Black, 3, RBLeaf, RBLeaf))
# Out:
# val t1 : int rbtree =
#   RBNode (Black, 2, RBNode (Black, 1, RBLeaf, RBLeaf),
#    RBNode (Black, 3, RBLeaf, RBLeaf))

# %%
let t2 = RBNode (Black, [2], 
  RBNode (Black, [1], RBLeaf, RBLeaf), 
  RBNode (Black, [3], RBLeaf, RBLeaf));;
rbf5 t2
# Out:
# val t2 : int list rbtree =
#   RBNode (Black, [2], RBNode (Black, [1], RBLeaf, RBLeaf),
#    RBNode (Black, [3], RBLeaf, RBLeaf))
# - : int list = [1; 2; 3]
