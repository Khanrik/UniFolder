# %%
#use_output "dune top"
#directory "pclib"
open Patricia;;
open Formula;;
open Substitution;;
#install_printer tprinter
#install_printer fprinter

# %%
subst ("y" |=> Var "x") (fparser "forall x. x = y")
# Out:
# - : Formula.fol Formula.formula = <<forall x'. x' = x>>

# %%
subst ("y" |=> Var "x") (fparser "forall x x'. x = y ==> x = x'")
# Out:
# - : Formula.fol Formula.formula = <<forall x' x''. x' = x ==> x' = x''>>

# %%
subst (("x" |-> (Var "y")) ("y" |=> Var "x")) (fparser "exists a b. x = a /\\ y = b")
# Out:
# - : Formula.fol Formula.formula = <<exists a b. y = a /\ x = b>>

# %%
subst (("z" |-> (Var "x'")) ("y" |=> Var "x")) (fparser "forall x x'. x = y ==> z = x'")
# Out:
# - : Formula.fol Formula.formula = <<forall x'' x'''. x'' = x ==> x' = x'''>>
