# %% [markdown]
# # KERNEL PCA

# %% [markdown]
# ## 1) Show that kernel PCA with a linear kernel function is equivalent to PCA.

# %% [markdown]
# A standard PCA is defined by the solution of the eigenvalue problem $S u_i = \lambda_i u_i$ based on the covariance matrix (page 602):
# $$
# S = \frac{1}{N} \sum_{n=1}^{N} x_n x_n^T = \frac{1}{N} XX^T
# $$
#
# The linear kernel function is defined as (page 310):
# $$
# k(x, x') = x^T x'
# $$
#
# A kernel PCA is defined by the solution of the eigenvalue problem $K a_i = \lambda_i N a_i$ (page 604) based on the kernel matrix (page 618):

# %% [markdown]
# ## 2) Show that kernel PCA with any kernel function corresponds to PCA applied to arbitrary (transformed data) representations $z_i$ of the original data $x_i \in \mathbb{R}^D$ for $i = 1,...,N$.

# %% [markdown]
# ## 3) Show that the dimensionality of the transformed data $z_i$ is at most equal to $D$.

# %% [markdown]
# # NONLINEAR CLASSIFICATION
# Two classes of a binary classification problem are given by the blue triangles and red circles in Figure 1.
#
# ![image.png](attachment:image.png)
#
# Please answer the following questions.

# %% [markdown]
# #
