# %% [markdown]
# ## Problem *7.1

# %% [markdown]
# ### (a)

# %% [markdown]
# ## Problem *7.3

# %% [markdown]
# ## Problem 7.4 (ikke vigtig siger daniel selv til eksamen)

# %% [markdown]
# Daniel siger der nok ikke kommer continuous time til eksamen, men spørg jakob, hvis noget.

# %% [markdown]
# ## Problem 7.6 (ikke vigtig siger daniel selv til eksamen)

# %% [markdown]
# ## Problem 7.24

# %% [markdown]
# Der er en fejl i A'eren
