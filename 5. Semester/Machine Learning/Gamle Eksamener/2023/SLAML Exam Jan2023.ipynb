# %% [markdown]
# # Topic 4

# %% [markdown]
# ## 6) (Score: 15%) If you were going to use linear activation functions for all the layers of the neural network, how would you optimize the parameters of the neural network? Explain why you would have to use that optimization process.

# %% [markdown]
# identity activation function

# %% [markdown]
# ## 7)

# %% [markdown]
# use normal linear regression since neural network will converge to the same answer, but requires a lot more computation to train it.
