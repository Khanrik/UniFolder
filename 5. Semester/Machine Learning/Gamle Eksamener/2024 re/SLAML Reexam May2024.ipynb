# %% [markdown]
# # Topic 1

# %% [markdown]
# ## 1) Estimate the mean of the Gaussian distribution, μM L, from the available data points by using the maximum likelihood (ML) method. (Score: 25%)

# %% [markdown]
# ## 2) Comment on whether the above mean estimate estimate, μM L, is biased OR unbiased. (Score: 15%)

# %% [markdown]
# ## 3) Estimate the covariance matrix of the Gaussian distribution. ΣM L, from the available data points by using the maximum likelihood (ML) method. (Score: 30%)

# %% [markdown]
# ## 4) Comment on whether the above covariance matrix estimate, ΣM L, is biased OR unbiased. If the above estimate is biased, how would you make it unbiased? (Score: 30%)

# %% [markdown]
# # Topic 2

# %% [markdown]
# HEW5

# %% [markdown]
# ## 1) (Score: 30%) Using the PCA method on the data set shown in Figure 2, obtain the principal components of the data.

# %% [markdown]
# # Topic 3

# %% [markdown]
# 2025 topic 2

# %% [markdown]
# slide 362

# %% [markdown]
# # Topic 4
