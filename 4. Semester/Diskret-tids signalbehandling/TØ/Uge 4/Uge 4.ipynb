# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# ## Problem 3.1

# %% [markdown]
# ### (a)

# %% [markdown]
# \begin{align*}
# X[z] &= \sum_{k = -\infty}^{\infty} \left( \frac{1}{2}  \right)^{k} (u[n] - u[n-10]) z^{-k}\\
# &= \sum_{k = 0}^{10} \left( \frac{1}{2}  \right)^{k} z^{-k}\\
# &= \frac{1 - \left( \frac{1}{2}z^{-1} \right)^{11}}{1 - \frac{1}{2}z^{-1}}\\
# &= \frac{1 - \frac{1}{2^{11}} z^{-11}}{1 - \frac{1}{2}z^{-1}}
# \end{align*}

# %% [markdown]
# ### (b)

# %% [markdown]
# \begin{align*}
# X[z] &= \sum_{k = -\infty}^{\infty} \left( \frac{1}{2}  \right)^{|n|} z^{-k}\\
# &= \sum_{k = 0}^{\infty} \left( \frac{1}{2}  \right)^{k} z^{-k} + \sum_{k = 1}^{\infty} \left( \frac{1}{2}  \right)^{k} z^{k}\\
# &= \sum_{k = 0}^{\infty} \left( \frac{1}{2}  \right)^{k} z^{-k} + \sum_{k = 0}^{\infty} \left( \frac{1}{2}  \right)^{k+1} z^{k+1}\\
# &= \frac{1}{1 - \frac{1}{2}z^{-1}} + \frac{1}{1 - \frac{1}{2}z}
# \end{align*}

# %% [markdown]
# ### (c)

# %% [markdown]
# \begin{align*}
# X[z] &= \sum_{k = -\infty}^{\infty} 5^{|k|} z^{-k}\\
# &= \sum_{k = 0}^{\infty} 5^{k} z^{-k} + \sum_{k = 1}^{\infty} 5^{k} z^{k}\\
# &= \sum_{k = 0}^{\infty} 5^{k} z^{-k} + \sum_{k = 0}^{\infty} 5^{k+1} z^{k+1}\\
# &= \frac{1}{1 - 5z^{-1}} + \frac{1}{1 - 5z}
# \end{align*}

# %% [markdown]
# ### (d)

# %% [markdown]
# \begin{align*}
# X[z] &= \sum_{k = -\infty}^{\infty} \left( \left( \frac{1}{2} \right)^{k} \cos\left( \frac{\pi}{3} k \right) \right) u[k] z^{-k}\\
# &= \frac{1 - \left( \frac{1}{2} \cos\left( \frac{\pi}{3} \right) z^{-1} \right)}{1 - 2\left( \frac{1}{2} \cos\left( \frac{\pi}{3} \right) \right) z^{-1} + r^{2}z^{-2}}
# \end{align*}
#
# **ROC:**
# $$
# |z| > \frac{1}{2}
# $$

# %% [markdown]
# ## Problem 3.3

# %% [markdown]
# \begin{align*}
# X[z] &= \sum_{k = -\infty}^{\infty} x[k] z^{-k}\\
# &= \sum_{k = 0}^{\infty} r^{k} \sin(\omega_{0}k) z^{-k} \\
# &= \sum_{k = 0}^{\infty} r^{k} \frac{e^{ j\omega_{0}k } - e^{ -j\omega_{0}k }}{2j} z^{-k}\\
# &= \frac{1}{2j} \left( \sum_{k = 0}^{\infty} r^{k} e^{ j\omega_{0}k } z^{-k} - \sum_{k = 0}^{\infty} r^{k} e^{ -j\omega_{0}k } z^{-k} \right)\\
# &= \frac{1}{2j} \left( \sum_{k = 0}^{\infty} (r e^{ j\omega_{0} } z^{-1})^{k} - \sum_{k = 0}^{\infty} (r e^{ -j\omega_{0} } z^{-1})^{k} \right)\\
# &= \frac{1}{2j} \left( \frac{1}{1 - r e^{ j\omega_{0} } z^{-1}} - \frac{1}{1 - r e^{ -j\omega_{0} } z^{-1}} \right)\\
# &= \frac{1}{2j} \frac{1 - r e^{ -j\omega_{0} } z^{-1} - 1 + r e^{ j\omega_{0} } z^{-1}}{(1 - r e^{ j\omega_{0} } z^{-1}) (1 - r e^{ -j\omega_{0} } z^{-1})}\\
# &= \frac{1}{2j} \frac{r e^{ j\omega_{0} } z^{-1} - r e^{ -j\omega_{0} } z^{-1}}{1 - r e^{ -j\omega_{0} } z^{-1} - r e^{ j\omega_{0} } z^{-1} + r^{2} e^{ 0 } z^{-2}}\\
# &= \frac{1}{2j} \frac{r (e^{ j\omega_{0} } - e^{ -j\omega_{0} }) z^{-1}}{1 - r (e^{ j\omega_{0} } + e^{ -j\omega_{0} }) z^{-1} + r^{2} z^{-2}}\\
# &= \frac{r \sin(\omega_{0}) z^{-1}}{1 - r 2 \cos(\omega_{0}) z^{-1} + r^{2} z^{-2}}\\
# &= \frac{r \sin(\omega_{0}) z^{-1}}{1 - 2 r \cos(\omega_{0}) z^{-1} + r^{2} z^{-2}}
# \end{align*}
