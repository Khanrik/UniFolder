# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# ## Problem *10.1
# bruger ligning 10.5

# %% [markdown]
# ### (a)

# %% [markdown]
# $$
# A_{p} = 20 \log_{10}\left( \frac{1 + \delta_{p}}{1 - \delta_{p}} \right) = 20 \log_{10}\left( \frac{1 + 0.01}{1 - 0.01} \right) = 0.173724
# $$
#
# $$
# A_{s} = 20 \log_{10}\left( \frac{1 + \delta_{p}}{\delta_{s}} \right) = 20 \log_{10}\left( \frac{1 + 0.01}{0.0001} \right) = 80.08643
# $$
#
# $$
# \epsilon = \sqrt{ 10^{(0.1 A_{p})} - 1 } = \sqrt{ 10^{(0.1 \cdot 0.173724)} - 1 } = 0.202020
# $$
#
# $$
# A = 10^{(0.05 A_{s})} = 10^{(0.05 \cdot 80.08643)} = 10100.0
# $$

# %% [markdown]
# ### (b)

# %% [markdown]
# $$
# \epsilon = 0.25 = \sqrt{ 10^{(0.1 \cdot A_{p})} - 1 } \implies A_{p} = 0.263289
# $$
#
# $$
# A = 200 = 10^{(0.05 A_{s})} \implies A_{s} = 46.0206
# $$
#
# $$
# A_{p} = 0.263289 = 20 \log_{10}\left( \frac{1 + \delta_{p}}{1 - \delta_{p}} \right) \implies \delta_{p} = 0.015155
# $$
#
# $$
# A_{s} = 46.0206 = 20 \log_{10}\left( \frac{1 + \delta_{p}}{\delta_{s}} \right) = 20 \log_{10}\left( \frac{1 + 0.015155}{\delta_{s}} \right) \implies \delta_{s} = 0.00507577
# $$

# %% [markdown]
# ## Problem 10.4

# %% [markdown]
# ## Problem 10.10

# %% [markdown]
# ## Problem 10.25
