# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Opgave 10.1

# %% [markdown]
# ![image.png](Opg10.1.png)

# %% [markdown]
# ### (a)

# %%
x = np.array([0.2, 0.3, 1.1, 1.3, 2.2, 2.4, 2.5])
a = np.vander(x, 4)
a.shape
# Out:
# (7, 4)

# %% [markdown]
# Da der er flere rækker end søjler kan man ikke finde en eksakt løsning. Det vil også betyde at mindste kvadraters løsning vil være lige så rigtig som at "løse" ligningssystemet.

# %% [markdown]
# ### (b)

# %%
u, s, vt = np.linalg.svd(a, full_matrices=False)

print("Singulærværdierne er:", s)

kA = s[0] / s[-1]

print("k(A) er:", kA)
# Out:
# Singulærværdierne er: [25.99958745  2.32596954  0.83772044  0.08837796]
# k(A) er: 294.1863285756074

# %% [markdown]
# ### (c)

# %%
b = np.array([1.6, -1.2, -0.3, 2.1, 2.3, -0.2, -1.3])[:, np.newaxis]

# %% [markdown]
# ### (d)

# %% [markdown]
# ## Opgave 10.2

# %% [markdown]
# Løs med proposition 18.12

# %% [markdown]
# Find standardmatrixrepræsentation med proposition 18.14
#
# eller eksempel 18.16 den er daniel approved som "god at have"
