# %% [markdown]
# ## (1) For each of the following expressions, is the expression well-typed? If it is well-typed, does it evaluate to a value? If so, what is the value?

# %%
1-2
# Out:
# - : int = -1

# %%
1-2-3
# Out:
# - : int = -4

# %%
1--2
# Out:
# File "[4]", line 1, characters 1-3:
# 1 | 1--2
#      ^^
# Error: Unbound value --

# %%
0b101 - 0x10
# Out:
# - : int = -11

# %%
1073741823 + 1
# Out:
# - : int = 1073741824

# %%
1073741823.0 + 1e2
# Out:
# File "[7]", line 1, characters 0-12:
# 1 | 1073741823.0 + 1e2
#     ^^^^^^^^^^^^
# Error: This expression has type float but an expression was expected of type
#          int

# %%
1 ^ 1
# Out:
# File "[8]", line 1, characters 0-1:
# 1 | 1 ^ 1
#     ^
# Error: This expression has type int but an expression was expected of type
#          string

# %%
if true then 1
# Out:
# File "[9]", line 1, characters 13-14:
# 1 | if true then 1
#                  ^
# Error: This expression has type int but an expression was expected of type
#          unit
#        because it is in the result of a conditional with no else branch

# %%
if false then ()
# Out:
# - : unit = ()

# %%
if 0.3 -. 0.2 = 0.1 then 'a' else 'b'
# Out:
# - : char = 'b'

# %%
true || (1 / 0 >= 0)
# Out:
# - : bool = true

# %%
1 > 2 - 1
# Out:
# - : bool = false

# %%
Hello world”.[6]
# Out:
# File "[15]", line 1, characters 6-12:
# 1 | Hello world”.[6]
#           ^^^^^^
# Alert deprecated: ISO-Latin1 characters in identifiers
# File "[15]", line 1, characters 12-13:
# 1 | Hello world”.[6]
#                 ^
# Error: Illegal character (\128)

# %%
Hello world”.[11] <- ’s’
# Out:
# File "[16]", line 1, characters 6-12:
# 1 | Hello world”.[11] <- ’s’
#           ^^^^^^
# Alert deprecated: ISO-Latin1 characters in identifiers
# File "[16]", line 1, characters 12-13:
# 1 | Hello world”.[11] <- ’s’
#                 ^
# Error: Illegal character (\128)

# %%
String.lowercase "A" < "B"
# Out:
# File "[17]", line 1, characters 0-16:
# 1 | String.lowercase "A" < "B"
#     ^^^^^^^^^^^^^^^^
# Alert deprecated: Stdlib.String.lowercase
# Use String.lowercase_ascii/StringLabels.lowercase_ascii instead.
# File "[17]", line 1, characters 0-16:
# 1 | String.lowercase "A" < "B"
#     ^^^^^^^^^^^^^^^^
# Alert deprecated: Stdlib.String.lowercase
# Use String.lowercase_ascii/StringLabels.lowercase_ascii instead.
# - : bool = false

# %%
Char.code 'a'
# Out:
# - : int = 97

# %%
(((())))
# Out:
# - : unit = ()

# %%
((((*1*))))
# Out:
# - : unit = ()

# %%
((*((()*))
# Out:
# - : unit = ()

# %% [markdown]
# ## (2) Which of the following let-expressions is legal? For each expression that is legal, give its type and the value that it evaluates to. Otherwise, explain why the expression is not legal.

# %%
let x = 1 in x
# Out:
# - : int = 1

# %%
let x = 1 in let y = x in y
# Out:
# - : int = 1

# %%
let x = 1 and y = x in y
# Out:
# File "[24]", line 1, characters 18-19:
# 1 | let x = 1 and y = x in y
#                       ^
# Error: Unbound value x

# %%
let x = 1 and x = 2 in x
# Out:
# File "[25]", line 1, characters 14-15:
# 1 | let x = 1 and x = 2 in x
#                   ^
# Error: Variable x is bound several times in this matching

# %%
let x = 1 in let x = x in x
# Out:
# - : int = 1

# %%
let a' = 1 in a' + 1
# Out:
# - : int = 2

# %%
let 'a = 1 in 'a + 1
# Out:
# File "[28]", line 1, characters 4-5:
# 1 | let 'a = 1 in 'a + 1
#         ^
# Error: Syntax error

# %% [markdown]
# ## (3) What is the value of the following expression:
# ```ocaml
# let x = 1 in let x = x + 1 in x
# ```

# %%
let x = 1 in let x = x + 1 in x
# Out:
# - : int = 2

# %% [markdown]
# ## (4) Write a “Hello world” program, which prints the line “Hello world!” to the standard output.

# %%
Printf.printf "Hello world!\n" ;;
# Out:
# - : unit = ()
